# %%
# %%capture
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg

# %%
# 1. Recebe o nome do arquivo
arquivo = input("Entre com o nome do arquivo de áudio/vídeo (ex: Audio4.mp3): ")

# 2. Divide o áudio em partes de 5 minutos
print("Dividindo o áudio em partes menores (5 min)...")
# !ffmpeg -i {arquivo} -f segment -segment_time 300 -c copy parte_%03d.mp3

# 3. Transcreve cada parte individualmente
import os
import glob

partes = sorted(glob.glob("parte_*.mp3"))

# tiny = Baixa - Muito rápido
# base = Boa - Razoável
# small = Muito boa -  Médio
# medium = Ótima - Lento

print("Transcrevendo...\n")
for i, parte in enumerate(partes):
    print(f"Transcrevendo {parte}...")
    # !whisper {parte} --model medium --task transcribe --language pt --output_format txt

print("✅ Transcrição finalizada. Baixe os arquivos .txt gerados.")
# Out:
# Entre com o nome do arquivo de áudio/vídeo (ex: Audio4.mp3): "Audio1.mp3"
# Dividindo o áudio em partes menores (5 min)...
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mp3, from 'Audio1.mp3':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:05:25.41, start: 0.025057, bitrate: 320 kb/s
#   Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 320 kb/s
#     Metadata:
#       encoder         : Lavc61.19
# [segment @ 0x59da838df540] Opening 'parte_000.mp3' for writing
# Output #0, segment, to 'parte_%03d.mp3':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 320 kb/s
#     Metadata:
#       encoder         : Lavc61.19
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [segment @ 0x59da838df540] Opening 'parte_001.mp3' for writing
# size=N/A time=00:05:25.35 bitrate=N/A speed=2.2e+03x
# video:0kB audio:12711kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# Transcrevendo...
#
# Transcrevendo parte_000.mp3...
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:36<00:00, 41.3MiB/s]
# [00:00.000 --> 00:06.480]  nada muito absurdo nos últimos dias. A gente teve muitas solicitações com relação a atendimento,
# [00:06.480 --> 00:13.880]  que foi algo que a gente já tinha te falado na primeira semana, mas não teve nenhuma... Acho que
# [00:13.880 --> 00:20.960]  não teve nenhuma solicitação muito absurda, não. Aqui a gente está com uma solicitação de documento aqui e aqui.
# [00:21.960 --> 00:32.960]  Algum erro na hora de lançar, porque a profissionalização era que a gente pensava no erro de processo ou no inativo, depois a gente olhava pra ver onde está isso aí.
# [00:33.960 --> 00:34.960]  O pé.
# [00:46.960 --> 00:51.960]  Essas que estão lá informou algum tipo de problema, a gente quer dar em tratativo ainda.
# [00:52.960 --> 00:53.960]  Isso.
# [01:13.960 --> 01:18.960]  Aqui pra mim não é de processo de movimentação, não. Aqui é atendimento.
# [01:18.960 --> 01:27.960]  Se o motivo principal dele ter diversas inconsistencias com o atendimento após buscar uma contadora, eu acho que é atendimento.
# [01:28.960 --> 01:32.960]  Produto plataforma de processo de movimentação.
# [01:49.960 --> 01:52.960]  Onde a gente está?
# [01:58.960 --> 02:00.960]  Tava no...
# [02:18.960 --> 02:26.960]  Mas esses aqui estão como cancelados.
# [02:27.960 --> 02:31.960]  O motivo não localizado. Será que é o que a gente não respondeu?
# [02:31.960 --> 02:36.960]  Abaixam. Ah, são aqueles que era do mês passado e vieram pra esse.
# [02:36.960 --> 02:39.960]  Que a gente não conseguiu...
# [02:39.960 --> 02:41.960]  Contato com esse?
# [02:41.960 --> 02:43.960]  Não, acho que esses aqui não estão cancelados ainda não.
# [02:43.960 --> 02:45.960]  Então sim.
# [02:49.960 --> 02:52.960]  A gente precisa de alguma resistência.
# [02:54.960 --> 02:59.960]  Aqueles dois debaixo é do mês passado.
# [02:59.960 --> 03:03.960]  Que a gente não conseguiu contactar e a gente só tem que alterar a observação.
# [03:03.960 --> 03:05.960]  A observação, fazer contato.
# [03:07.960 --> 03:17.960]  Com mensalidade, a gente tem uma presença ativa, uma por custo, chat, é o de processo de atendimento.
# [03:17.960 --> 03:20.960]  Aquele lá entra aqui pra gente.
# [03:25.960 --> 03:31.960]  A gente tem 64 reversíveis.
# [03:31.960 --> 03:35.960]  Do mês são 23 obrigatórios.
# [03:38.960 --> 03:40.960]  41 reversíveis.
# [03:40.960 --> 03:46.960]  É porque a gente teve um boom muito grande de cliente de problemas de atendimentos.
# [03:46.960 --> 03:49.960]  Mas isso não faz refletimento aqui, né?
# [03:53.960 --> 03:59.960]  Talvez a gente esteja avaliando na hora de colocar o cancelamento igual a gente avalia a ouvidoria.
# [03:59.960 --> 04:03.960]  Talvez a gente tenha que mudar um pouco a percepção.
# [04:03.960 --> 04:05.960]  Dos obrigatórios, né?
# [04:05.960 --> 04:06.960]  É.
# [04:06.960 --> 04:10.960]  Aqui, por exemplo, é o modelo de negócio. Vamos ver.
# [04:11.960 --> 04:16.960]  Aqui também é atendimento.
# [04:25.960 --> 04:28.960]  Aqui é atendimento, aqui...
# [04:29.960 --> 04:32.960]  Esse aqui é o modelo de negócio, aquele ali.
# [04:32.960 --> 04:36.960]  Porque o modelo de negócio, o atendimento não atenderia a ele.
# [04:36.960 --> 04:38.960]  Por exemplo, o telefone.
# [04:38.960 --> 04:43.960]  Então, a gente tem o toano por telefone.
# [04:43.960 --> 04:44.960]  É?
# [04:44.960 --> 04:45.960]  É.
# [04:45.960 --> 04:48.960]  Que ele pode acendir também por telefone, que é o toano.
# [04:49.960 --> 04:51.960]  Não sabia.
# [04:51.960 --> 04:52.960]  Só não sabia.
# [04:52.960 --> 04:54.960]  Pronto, clica, sei lá.
# [04:56.960 --> 04:58.960]  Não sabia disso não?
# [04:58.960 --> 04:59.960]  Também não.
# Transcrevendo parte_001.mp3...
# [00:00.000 --> 00:02.000]  No último plano ele pode...
# [00:02.000 --> 00:04.000]  No março?
# [00:06.000 --> 00:10.000]  Aí aqui também está cancelado, mas ainda está com a conservação hidratativa.
# [00:10.000 --> 00:14.000]  Está com a pendência do cliente.
# [00:16.000 --> 00:20.000]  A enrolação, desabertura, pendência cliente e observação hidratativa.
# [00:20.000 --> 00:22.000]  Mas ele está cancelado.
# [00:22.000 --> 00:24.000]  Tá.
# [00:24.000 --> 00:26.000]  Preciso de um tema.
# ✅ Transcrição finalizada. Baixe os arquivos .txt gerados.

# %%
# 6. Juntar todas as transcrições em um único arquivo final
arquivos_txt = sorted(glob.glob("parte_*.txt"))

with open("transcricao_final.txt", "w", encoding="utf-8") as final:
    for nome_txt in arquivos_txt:
        with open(nome_txt, "r", encoding="utf-8") as f:
            final.write(f"### {nome_txt} ###\n")
            final.write(f.read() + "\n\n")

print("✅ Transcrição final unificada em: transcricao_final.txt")
# Out:
# ✅ Transcrição final unificada em: transcricao_final.txt

# %%
#Excluir todos os arquivos para iniciar uma nova transcrição, OBS: atualize no botão após a exclusão
# !rm *.mp3
# !rm *.txt
# !rm -r whisper  # se tiver uma pasta gerada
# Out:
# rm: cannot remove 'whisper': No such file or directory
