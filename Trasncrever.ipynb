# %% [markdown]
# <a href="https://colab.research.google.com/github/janilsonpassos/transcritor-whisper/blob/main/Trasncrever.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg

# %%
# 1. Recebe o nome do arquivo
arquivo = input("Entre com o nome do arquivo de áudio/vídeo (ex: Audio4.mp3): ")

# 2. Divide o áudio em partes de 5 minutos
print("Dividindo o áudio em partes menores (5 min)...")
# !ffmpeg -i {arquivo} -f segment -segment_time 300 -c copy parte_%03d.mp3

# 3. Transcreve cada parte individualmente
import os
import glob

partes = sorted(glob.glob("parte_*.mp3"))

# tiny = Baixa - Muito rápido
# base = Boa - Razoável
# small = Muito boa -  Médio
# medium = Ótima - Lento

print("Transcrevendo...\n")
for i, parte in enumerate(partes):
    print(f"Transcrevendo {parte}...")
    # !whisper {parte} --model medium --task transcribe --language pt --output_format txt

print("✅ Transcrição finalizada. Baixe os arquivos .txt gerados.")
# Out:
# Entre com o nome do arquivo de áudio/vídeo (ex: Audio4.mp3): 'Recorded video - Jun 13, 2025.mp3'
# Dividindo o áudio em partes menores (5 min)...
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mp3, from 'Recorded video - Jun 13, 2025.mp3':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Duration: 00:37:17.18, start: 0.023021, bitrate: 128 kb/s
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavc61.3.
# [segment @ 0x56e1b1a84280] Opening 'parte_000.mp3' for writing
# Output #0, segment, to 'parte_%03d.mp3':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavc61.3.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [segment @ 0x56e1b1a84280] Opening 'parte_001.mp3' for writing
# [segment @ 0x56e1b1a84280] Opening 'parte_002.mp3' for writing
# [segment @ 0x56e1b1a84280] Opening 'parte_003.mp3' for writing
# [segment @ 0x56e1b1a84280] Opening 'parte_004.mp3' for writing
# [segment @ 0x56e1b1a84280] Opening 'parte_005.mp3' for writing
# [segment @ 0x56e1b1a84280] Opening 'parte_006.mp3' for writing
# [segment @ 0x56e1b1a84280] Opening 'parte_007.mp3' for writing
# size=N/A time=00:37:17.13 bitrate=N/A speed=2.98e+03x
# video:0kB audio:34956kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# Transcrevendo...
#
# Transcrevendo parte_000.mp3...
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:13<00:00, 117MiB/s]
# [00:00.000 --> 00:10.000]  Ah, então, porque é isso, assim, é o que a gente falou, não, meu bem, tá num presumido.
# [01:00.000 --> 01:10.000]  Ah, então, porque é isso, assim, é o que a gente falou, não, meu bem, tá num presumido.
# [01:30.000 --> 01:40.000]  Ah, então, porque é isso, assim, é o que a gente falou, não, meu bem, tá num presumido.
# [02:00.000 --> 02:10.000]  Ah, então, porque é isso, assim, é o que a gente falou, não, meu bem, tá num presumido.
# [03:00.000 --> 03:05.000]  à referência a você o seu primeiro opinário de horário é muito bom
# [03:05.000 --> 03:08.000]  a gente também as ideias específicas ali
# [03:08.000 --> 03:12.000]  você já acreditou em saber o que é o que a gente está fazendo
# [03:12.000 --> 03:13.000]  entende?
# [03:13.000 --> 03:14.000]  tá?
# [03:14.000 --> 03:19.000]  mas aí a avançada sensação é que a gente está assistindo tudo o que a gente está fazendo
# [03:19.000 --> 03:23.000]  e agora é só pra falar o que a gente está fazendo final
# [03:30.000 --> 03:35.000]  tudo
# [03:35.000 --> 03:39.000]  joia, seja muito bem-vindo
# [03:39.000 --> 03:41.000]  imagina
# [03:41.000 --> 03:46.000]  Jonathan, eu vou te passar aqui como funcionam as funções da plataforma
# [03:46.000 --> 03:49.000]  como que ela vai interagir com a sua rotina mensal
# [03:49.000 --> 03:51.000]  mas antes de eu começar a te passar
# [03:51.000 --> 03:54.000]  eu queria saber se você tem alguma dúvida pontual
# [03:54.000 --> 03:57.000]  se você gostaria de esclarecer alguma coisa
# [04:00.000 --> 04:02.000]  tá
# [04:18.000 --> 04:21.000]  entendi, não tem problema, tá?
# [04:21.000 --> 04:24.000]  eu vou te passar aqui as funções
# [04:24.000 --> 04:27.000]  mas deixa eu dar uma olhada aqui na questão da nota
# [04:27.000 --> 04:30.000]  você está falando pra mim que ele não teve condições de ficar mexendo
# [04:33.000 --> 04:36.000]  tá, em maio você realmente não teve emissão
# [04:36.000 --> 04:39.000]  ou você teve emissão mas não importou?
# [04:48.000 --> 04:51.000]  tá, então me avisa depois
# [04:51.000 --> 04:54.000]  tá bom se você teve realmente
# [04:54.000 --> 04:58.000]  porque daí a gente reabre aqui o período pra incluir essa emissão aqui
# [04:58.000 --> 05:01.000]  pra sua empresa manter regular
# Transcrevendo parte_001.mp3...
# [00:00.000 --> 00:19.080]  Então, é muito importante porque a gente precisa fazer a apuração dessas emissões.
# [00:19.080 --> 00:29.160]  É claro que vai girar o imposto e tudo, mas a empresa fica regular, tá bom?
# [00:29.160 --> 00:37.280]  Clica lá no cadastrar senha nova, clica lá em esquecer minha senha e coloca uma senha nova.
# [00:37.280 --> 00:42.520]  O seu e-mail é esse que está aparecendo aqui na plataforma, né? É esse que você está usando.
# [00:42.520 --> 01:03.480]  Na verdade, era para ser até o contrário, né? Porque os celulares não lê a plataforma completa.
# [01:12.520 --> 01:30.120]  Então, eu vou até anotar aqui que aqui no final eu já vou solicitar a reabertura do período, tá?
# [01:43.080 --> 01:54.440]  A abertura de maio. Você está com a plataforma aberta no celular nesse momento?
# [01:54.440 --> 02:05.240]  Será que não fica melhor se você deslogar? Só para garantir que não é esse o problema.
# [02:05.240 --> 02:12.840]  Bem, a gente está com três acessos, né? Tentando fazer três acessos porque eu estou com ela aberta aqui, você no celular.
# [02:26.840 --> 02:32.280]  No caso do meio, o que acontece? O imposto é fixo, né?
# [02:32.280 --> 02:38.120]  Então, você emitindo nota ou não, trabalhando ou não, vai ter o imposto.
# [02:38.120 --> 02:40.120]  Você tem...
# [02:44.120 --> 02:46.120]  Isso é isso mesmo.
# [02:48.120 --> 02:52.120]  Mas você tem a MEI e essa empresa no seu nome?
# [02:56.120 --> 02:58.120]  Deixa eu só ver uma informação aqui.
# [03:02.280 --> 03:22.120]  Ah, tá. Essa empresa é a MEI.
# [03:22.120 --> 03:28.120]  Ah, que susto. Eu tinha entendido que era outra empresa.
# [03:32.280 --> 03:48.120]  Mas por que você fala que está acontecendo algum problema mesmo com a MEI ou é só questão de dificuldade?
# [03:52.120 --> 03:56.120]  Ah, entendi.
# [03:56.960 --> 04:05.960]  Sim, tem bastante gente migrando da MEI para a EMI que é mais fácil.
# [04:05.960 --> 04:13.960]  Tem recolhimentos, um outro processo, mas fica tudo bem separadinho, fica mais fácil de controlar.
# [04:26.960 --> 04:35.960]  E a sua empresa trabalha de forma física, você tem um endereço físico.
# [04:35.960 --> 04:37.960]  É, precisa.
# [04:37.960 --> 04:41.960]  Precisa, mas vale a pena fazer essas alterações.
# [04:41.960 --> 04:48.960]  Até por conta do faturamento, né? Porque se você desenquadra sozinho com o faturamento,
# [04:48.960 --> 04:58.800]  aí é uma dor de cabeça, a receita desenquadra, mas aí você precisa fazer o processo de enquadramento.
# Transcrevendo parte_002.mp3...
# [00:00.000 --> 00:02.920]  que está sozinho, acaba dando uma dor de cabeça ali.
# [00:02.920 --> 00:05.780]  É mais fácil mesmo você se programar, falar,
# [00:05.780 --> 00:09.300]  a partir de tal data, vou fazer o desenquadramento, o enquadramento,
# [00:09.300 --> 00:13.880]  e aí seguir ali de acordo com o seu planejamento, para não ter surpresas.
# [00:16.040 --> 00:20.400]  Bom, eu vou te passar aqui, então, o cenário do controle geral da plataforma,
# [00:20.400 --> 00:26.040]  mas eu vou te pontuando ali o que você vai usar com a MEI, tá?
# [00:27.040 --> 00:31.880]  Deixa eu ver se eu consigo aumentar um pouquinho mais a tela aqui.
# [00:31.880 --> 00:32.880]  Pronto.
# [00:33.880 --> 00:35.880]  Ah, que bom!
# [00:37.880 --> 00:38.880]  Maravilha.
# [00:38.880 --> 00:43.680]  Bom, então, essa questão, deixa eu começar aqui por cima,
# [00:43.680 --> 00:48.280]  deixa eu, desde o comecinho aqui, que eu acho que fica melhor para a gente abordar os pontos,
# [00:48.280 --> 00:50.280]  uma coisa vai ligando a outra.
# [00:51.280 --> 00:56.000]  Aqui em cima, a gente tem dois botões, que é o suporte e a minha empresa.
# [00:56.000 --> 01:02.520]  Aqui no suporte, você vai ter o acesso a tutoriais, abrir e gerenciar chamados e chat.
# [01:02.520 --> 01:04.320]  Chamados são históricos de atendimento,
# [01:04.320 --> 01:07.520]  são atendimentos também que podem estar acontecendo.
# [01:07.520 --> 01:11.080]  E quando que você vai abrir um chamado ou abrir um chat?
# [01:11.080 --> 01:14.720]  O prazo de retorno do chamado é de até 24 horas úteis.
# [01:14.720 --> 01:19.520]  Então, aqui você só vai abrir se for um caso que requer uma análise mais profunda,
# [01:19.560 --> 01:23.160]  que vai demandar um tempo maior para te entregar essas informações,
# [01:23.160 --> 01:28.960]  porque talvez pode depender de prazos de órgãos externos, os órgãos públicos.
# [01:28.960 --> 01:31.920]  Quando for uma coisa pontual que você precisa saber,
# [01:31.920 --> 01:36.560]  uma informação precisa colocar na nota fiscal, ou informação por tributação.
# [01:36.560 --> 01:39.200]  Se as informações são mais rápidas, sempre aqui no chat,
# [01:39.200 --> 01:42.800]  porque aqui o time já vai te responder no acesso que você fizer.
# [01:42.800 --> 01:47.120]  Você não vai precisar ficar esperando 24 horas para ter esse retorno, tá bom?
# [01:48.080 --> 01:54.840]  E aqui no gerenciar é onde você vai ter acesso a essas informações que também foram finalizadas.
# [01:54.840 --> 01:59.760]  Então, se você acessar o chat hoje, conversou, resolveu, fechou ali, acabou.
# [01:59.760 --> 02:02.800]  Passar três meses você precisa rever aquela informação,
# [02:02.800 --> 02:07.520]  aqui no gerenciar você vai ter acesso, você consegue ver todos os históricos, tá bom?
# [02:09.040 --> 02:12.880]  Aqui no Minha Empresa é onde ficam os dados da sua empresa.
# [02:12.960 --> 02:18.720]  Então, aqui é como se fosse um atalho para esses dados básicos da sua empresa.
# [02:18.720 --> 02:25.240]  Então, aqui você consegue alterar senha, e-mail, e aqui embaixo você vai ter o CNPJ,
# [02:25.240 --> 02:28.320]  o contrato social, no caso o CC-MAIL, enfim.
# [02:28.320 --> 02:32.080]  Todas essas informações ficam disponíveis ali para...
# [02:32.080 --> 02:36.800]  De repente você está na rua e precisa pegar uma informação dessas, não lembra ali de cabeça?
# [02:36.800 --> 02:39.520]  Acessa a plataforma, não precisa acessar o chat nem nada,
# [02:39.520 --> 02:42.720]  só vem aqui no Minha Empresa e você já tem esses dados, tá?
# [02:44.480 --> 02:50.320]  E aqui também a gente tem o contrato de prestação de serviço com a senhora contada.
# [02:50.320 --> 02:52.000]  Deixa eu abrir ele aqui.
# [02:54.960 --> 02:57.760]  Está vendo aqui que ele já tem o Anseite, né?
# [02:59.520 --> 03:03.120]  Se você tiver qualquer dúvida sobre qualquer informação que tem aqui no contrato,
# [03:03.120 --> 03:05.920]  dá um toque para a gente esclarecer para você.
# [03:05.920 --> 03:08.880]  Esse contrato ali não some dali, então mesmo com o Anseite,
# [03:08.880 --> 03:12.720]  ele fica disponível ali para você no Minha Empresa, tá?
# [03:14.400 --> 03:18.000]  Aqui nessa tela inicial a gente também tem um quadro de lembretes.
# [03:18.000 --> 03:21.120]  Então, você vê que aqui tem algumas datas, né?
# [03:21.120 --> 03:24.720]  É legal ficar atento a essas datas, mesmo porque essas datas alteram.
# [03:24.720 --> 03:26.400]  Elas sempre estão atualizadas.
# [03:26.400 --> 03:27.680]  Por quê?
# [03:27.680 --> 03:31.520]  Existem prazos que são mais rígidos, mais, né?
# [03:31.520 --> 03:34.320]  São fixos, por exemplo, o pagamento dos impostos, né?
# [03:34.320 --> 03:37.360]  No seu caso da MEI, que tem a guia do MEI também, né?
# [03:37.360 --> 03:38.080]  Das MEI.
# [03:39.280 --> 03:41.200]  O vencimento é sempre no dia 20.
# [03:41.200 --> 03:45.120]  Se acontecer desse dia 20 ser um final de semana ou um feriado, por exemplo,
# [03:45.120 --> 03:46.720]  pode adiantar o PosterGAP.
# [03:46.720 --> 03:51.520]  Então, aqui vai estar informando para você se adiantou, se postergou, qualquer data.
# [03:51.520 --> 03:54.320]  Tá legal estar sempre de olho ali para não perder nenhum prazo, tá?
# [03:56.320 --> 03:58.320]  Aqui a gente tem o botãozinho da Ovidoria.
# [03:58.320 --> 04:02.880]  Então, se você precisar de um reforço, de um atendimento que você esteja tendo,
# [04:02.880 --> 04:08.320]  clica aqui, o time vai receber a sua solicitação, vai dando andamento com você nessa tratativa.
# [04:08.320 --> 04:13.600]  E aqui embaixo a gente tem o quadro, que são os chamados, são os mesmos chamados que aparecem aqui.
# [04:13.600 --> 04:18.160]  Você clicando aqui ou lá, você vai ser direcionado para essa mesma área.
# [04:18.160 --> 04:20.240]  Aqui ficam os chamados mais recentes, né?
# [04:20.240 --> 04:23.760]  Então, vai alternando aqui, mas você clicando aqui, você consegue ver todos,
# [04:23.760 --> 04:25.440]  até os que estão finalizados, tá?
# [04:26.640 --> 04:30.560]  E aqui embaixo essa bolha é a bolha para o processo ao chat também,
# [04:30.640 --> 04:35.840]  é um atalho aí que você consegue acessar por aqui ou aqui em cima no botão do suporte.
# [04:37.840 --> 04:43.840]  Essa tela que a gente tem aberta aqui, ela é desse segundo menu, é esse primeiro botão.
# [04:43.840 --> 04:50.640]  E essa tela aqui se refere à oferta de algumas parcerias que a Sr. Contábil tem.
# [04:50.640 --> 04:56.240]  Então, ela oferta aqui o banco fora, parceria com seguro, parceria com certificado digital,
# [04:56.240 --> 04:59.040]  que pode ser a primeira contratação ou renovação.
# [04:59.040 --> 04:59.920]  Se você sentir falso...
# Transcrevendo parte_003.mp3...
# [00:00.000 --> 00:03.120]  de algum serviço externo, dá um toque aqui pra gente, pode ser que a gente tenha
# [00:03.120 --> 00:07.480]  uma parceria que acabe oferecendo aí uma condição diferente,
# [00:07.480 --> 00:12.440]  especial por você ser cliente aqui da Sr. Contávio.
# [00:12.440 --> 00:15.240]  Até aí, ok?
# [00:16.240 --> 00:20.120]  Vamos entrar lá na questão agora de notas fiscais, tá?
# [00:20.120 --> 00:23.640]  Vou trocar aqui a corda da minha canetinha.
# [00:23.640 --> 00:26.800]  Pronto. Vamos lá, notas fiscais.
# [00:26.840 --> 00:33.040]  O MEI, ele não tem obrigatoriedade de emitir nota se essa nota é pra uma pessoa física.
# [00:33.040 --> 00:38.240]  Mas é interessante que você faça porque a nota é um cuidado seu com a sua empresa, né?
# [00:38.240 --> 00:43.240]  O MEI não vai fazer diferença ali na questão financeira em relação a impostos nem nada.
# [00:43.240 --> 00:48.200]  Então é legal que você tenha essa prática pra você mesmo, pra controle da sua empresa, tá?
# [00:48.200 --> 00:52.480]  Emitiu a nota, tá lá no processo de emissão da nota.
# [00:52.480 --> 00:55.040]  Vai ter um botãozinho lá na plataforma da sua prefeitura,
# [00:55.400 --> 01:00.320]  no acesso que você faz, pra baixar a XML.
# [01:00.320 --> 01:03.480]  Baixou, salva ela numa pastinha no seu computador.
# [01:03.480 --> 01:04.760]  Por quê?
# [01:04.760 --> 01:11.000]  Pra trazer essa nota aqui pra plataforma, você pode trazer uma vez por dia, por semana,
# [01:11.000 --> 01:13.160]  quinzenal, mensal.
# [01:13.160 --> 01:18.920]  E aí, você tendo ela salva ali nessa pastinha, fica mais fácil pra você fazer esse controle
# [01:18.920 --> 01:21.880]  e fazer essas importações, né?
# [01:21.880 --> 01:23.600]  E aí o que acontece?
# [01:23.600 --> 01:29.720]  Você tem até 5 dias do mês seguinte pra trazer essa nota aqui pra plataforma.
# [01:29.720 --> 01:35.200]  Então vamos supor, tudo que você emitiu do dia 1º até o dia 31 de maio,
# [01:35.200 --> 01:38.720]  você ainda teve até o dia 5 de junho pra pôr aqui.
# [01:38.720 --> 01:45.120]  É importante estar sempre atento, porque mesmo que você esteja fazendo esse processo de importação
# [01:45.120 --> 01:51.800]  no mês de junho, a nota tem que ser importada dentro do mês de referência da emissão dela, tá?
# [01:51.800 --> 01:54.880]  Então se ela foi emitida em maio, importa em maio.
# [01:54.880 --> 02:00.440]  Como já passou o dia 5, eu preciso pedir pro time liberar aqui, se você clicar aqui,
# [02:00.440 --> 02:07.040]  ele vai informar que acabou o período e ele tá te cobrando uma taxinha de 48 reais pra reabrir esse prazo.
# [02:07.040 --> 02:11.360]  Como você não tinha feito treinamento antes, eu vou pedir a reabertura do prazo,
# [02:11.360 --> 02:15.000]  enzentando você dessa taxinha, tá?
# [02:22.640 --> 02:28.120]  Você que sabe, tá? Porque aí vai ter aqui o seu controle.
# [02:30.120 --> 02:32.600]  Você prefere? Tá bom.
# [02:32.600 --> 02:36.120]  Então eu não vou abrir esse chamado, tá?
# [02:36.120 --> 02:38.480]  E aí como que vai funcionar?
# [02:38.480 --> 02:40.640]  Emetiu a nota, salvou na pastinha.
# [02:40.640 --> 02:42.600]  Ah, eu quero fazer só no final do mês.
# [02:42.600 --> 02:45.760]  Vou vir aqui só no dia 30, vou trazer só no dia 30.
# [02:45.760 --> 02:47.320]  Sem problemas.
# [02:47.360 --> 02:50.600]  Aí clica aqui no importar nota, né?
# [02:50.600 --> 02:53.600]  Do mês que você vai trazer essas notas.
# [02:53.600 --> 02:57.480]  Aí a plataforma vai te perguntar se essa nota foi emitida pro exterior.
# [02:57.480 --> 03:01.160]  Se sim ou não, clica aqui pra responder.
# [03:01.160 --> 03:04.720]  E aí em selecionar que ele vai abrir um campo de pesquisa no seu computador,
# [03:04.720 --> 03:07.320]  localiza a pastinha onde salvou essas xml,
# [03:07.320 --> 03:11.320]  seleciona lá quais são as que você vai trazer pra plataforma indiferente,
# [03:11.320 --> 03:16.760]  se você vai trazer uma nota por vez ou 50, tá?
# [03:16.840 --> 03:20.600]  Seleciona, dá o OK e pronto, ela vai subir as notas.
# [03:20.600 --> 03:26.600]  Aqui em arquivo, ela vai dizer se essa nota foi processada ou se ela tem algum erro.
# [03:26.600 --> 03:30.960]  Se tiver qualquer divergência no processo de emissão ou de importação,
# [03:30.960 --> 03:34.480]  vai apontar um erro, aí é interessante que você acesse o suporte
# [03:34.480 --> 03:37.120]  pra gente verificar o que aconteceu, fazer a correção,
# [03:37.120 --> 03:39.400]  trabalhar ali pra deixar tudo redondinho pra você.
# [03:39.400 --> 03:41.960]  Se tá escrito processado, tá tudo certo,
# [03:41.960 --> 03:46.160]  a plataforma leu conseguiu interagir com o documento, tá?
# [03:46.200 --> 03:51.400]  Aqui ela vai somar a quantidade de notas e aqui ela vai te dar uma prévia do seu faturamento.
# [03:51.400 --> 03:55.000]  Então, conforme você vai importando notas,
# [03:55.000 --> 03:57.160]  ela vai somando o valor dessas notas aqui,
# [03:57.160 --> 04:02.080]  aí você consegue ter aqui uma prévia do dinheiro que tá entrando na sua empresa, tá?
# [04:03.080 --> 04:04.080]  Como...
# [04:14.360 --> 04:17.040]  Sim, hoje, como você tá no MEI,
# [04:17.040 --> 04:20.320]  você não tem assim essa obrigatoriedade, esse controle mesmo,
# [04:20.320 --> 04:25.400]  porque o seu imposto já tá dentro ali, né, da DAS.
# [04:25.400 --> 04:28.920]  Você emitindo nota ou não, a sua empresa tendo faturamento ou não,
# [04:28.920 --> 04:33.160]  você acaba tendo ali a obrigatoriedade de pagar o imposto, né?
# [04:33.160 --> 04:35.920]  Mas quando você for pra ME, por exemplo,
# [04:35.920 --> 04:41.680]  aí é importante que esteja tudo aqui pra que você não tenha problema fiscal lá com a receita,
# [04:41.680 --> 04:47.360]  porque aí faz a apuração dentro da realidade dos trabalhos que a sua empresa realiza, tá?
# [04:48.760 --> 04:56.080]  E aqui na plataforma, você tem aqui algumas opções de importação,
# [04:56.080 --> 04:59.920]  porque o seu CNPJ tá ali configurado...
# Transcrevendo parte_004.mp3...
# [00:00.000 --> 00:06.660]  e a informação de que você tem atividades do segmento de comércio e serviços.
# [00:06.660 --> 00:11.160]  Então, nesses casos, você também pode importar aqui na plataforma,
# [00:11.160 --> 00:14.700]  quando forem notas de comércio,
# [00:14.700 --> 00:21.600]  as notas que são emitidas contra o seu CNPJ, que são as notas recebidas.
# [00:23.100 --> 00:24.100]  Então, aqui...
# [00:25.100 --> 00:29.100]  É dentro do MEI, não?
# [00:33.100 --> 00:40.100]  Porque, na verdade, vai servir como controle essas notas que você recebe.
# [00:40.100 --> 00:46.100]  Porque, normalmente, quem trabalha na área de comércio faz compra de itens para vender.
# [00:46.100 --> 00:53.100]  Então, vai ter esse controle ali, mas o que você paga de fato ali é dentro das suas emissões.
# [00:54.100 --> 00:57.100]  Na verdade, não das emissões em si, é das movimentações,
# [00:57.100 --> 01:01.100]  porque a receita sabe o que está correndo ali dentro da sua conta.
# [01:04.100 --> 01:08.100]  Então, você não tem obrigatoriedade de informar pro labore,
# [01:08.100 --> 01:14.100]  porque o pro labore é o salário do sócio, porque a receita precisa recolher o INSS.
# [01:14.100 --> 01:19.100]  Como você já paga tudo numa guia só, não tem porquê vir aqui e informar,
# [01:19.100 --> 01:22.100]  porque é para recolher duas vezes.
# [01:22.100 --> 01:25.100]  Quando você for ME, vai ter uma regrinha,
# [01:25.100 --> 01:29.100]  e aí, nessa regrinha, você vai precisar informar pro labore aqui e recolher o INSS,
# [01:29.100 --> 01:32.100]  que vai ser gerada uma guia à parte do INSS.
# [01:32.100 --> 01:34.100]  Está me ouvindo bem?
# [01:41.100 --> 01:45.100]  Então, é bastante legal, dependendo do seu ato ali com o faturamento.
# [01:45.100 --> 01:47.100]  Vamos supor que você tenha um faturamento de 10 mil.
# [01:47.100 --> 01:52.100]  E aí, você quer informar só um salário mínimo como pro labore,
# [01:52.100 --> 01:54.100]  e recolher só 11% disso.
# [01:54.100 --> 01:57.100]  Ok, o restante do lucro é a distribuição de lucro,
# [01:57.100 --> 02:02.100]  e aí esse valor não entra para a contagem lá do seu imposto de renda de pessoa física.
# [02:06.100 --> 02:13.100]  É, porque você já vai pagar o tributo aqui sobre o seu faturamento, independente.
# [02:13.100 --> 02:15.100]  Ele já vai ter que pagar ali.
# [02:15.100 --> 02:19.100]  E aí, se esse dinheiro só corre solto na sua conta de pessoa física,
# [02:19.100 --> 02:25.100]  você acaba tendo que pagar outro tributo lá dos 27,5% de pessoa física,
# [02:25.100 --> 02:26.100]  sendo que você já pagou aqui.
# [02:26.100 --> 02:30.100]  Então, quando vai lá a distribuição de lucro, você não tem essa tarifa de novo.
# [02:32.100 --> 02:39.100]  Dentro dessas outras áreas, você tem um controle maior do que está acontecendo financeiramente na sua empresa,
# [02:39.100 --> 02:42.100]  e também como pessoa física, porque aí isso não fica...
# [02:42.100 --> 02:47.100]  Imagina, você fica deixando esse dinheiro correndo solto ali como pessoa física,
# [02:47.100 --> 02:49.100]  vai lá declarar o imposto de renda, você vai pagar...
# [02:49.100 --> 02:55.100]  Já pagou aqui, por exemplo, no MEI mesmo, já está pagando aqui a sua guia DAS.
# [02:56.100 --> 02:58.100]  Deixa eu fazer o acesso novamente, caiu.
# [03:01.100 --> 03:06.100]  Aí, você vai lá e paga lá 27,5% para declarar o imposto de renda como pessoa física.
# [03:13.100 --> 03:15.100]  Ainda não foi gerada a guia para você.
# [03:18.100 --> 03:19.100]  Bom, mas o mais é isso.
# [03:19.100 --> 03:22.100]  Depois você vai precisar informar aqui o Prolaborio, tá?
# [03:22.100 --> 03:24.100]  Mas nesse momento, não.
# [03:25.100 --> 03:30.100]  Quando que vai estar aqui na área de impostos as guias para o pagamento do MEI?
# [03:31.100 --> 03:32.100]  Sempre dia 15.
# [03:32.100 --> 03:34.100]  Entra aqui dia 15 e já vai ter a guia aqui.
# [03:35.100 --> 03:40.100]  Essa guia vai ter o campo aqui para você fazer o download,
# [03:40.100 --> 03:42.100]  que você consegue abrir o arquivo antes de fazer o pagamento.
# [03:42.100 --> 03:45.100]  Tem lá o CNP, o código de barras,
# [03:45.100 --> 03:50.100]  o pagamento já vai direto lá para o órgão público que solicita o pagamento desse imposto.
# [03:50.100 --> 03:52.100]  Fez o pagamento, altera aqui.
# [03:53.100 --> 03:55.100]  Aqui, sempre vai estar informando que não foi pago.
# [03:56.100 --> 03:57.100]  Aí, muda de não para sim.
# [03:58.100 --> 04:00.100]  Coloca a data que você fez o pagamento, fechou,
# [04:00.100 --> 04:04.100]  porque aí vai te dar um controle desses pagamentos de impostos.
# [04:04.100 --> 04:07.100]  Então, aqui, sempre vai estar informando o mês por atrás.
# [04:07.100 --> 04:11.100]  Então, se a gente está falando de junho, aqui vai estar informando maio de 2025.
# [04:12.100 --> 04:13.100]  E assim sucessivamente.
# [04:13.100 --> 04:16.100]  O nome do imposto, o valor, a data de vencimento.
# [04:20.100 --> 04:22.100]  Declarações, as declarações obrigatórias.
# [04:22.100 --> 04:24.100]  Ficam nessa aba aqui das declarações.
# [04:24.100 --> 04:27.100]  Então, a gente faz as declarações obrigatórias.
# [04:28.100 --> 04:31.100]  Depois de fazer a entrega, tudo certinho, disponibiliza aqui para você.
# [04:31.100 --> 04:35.100]  Você consegue também fazer o download desse documento, guardar com você,
# [04:35.100 --> 04:38.100]  mas ele também fica aqui para controle seu.
# [04:40.100 --> 04:43.100]  A gente tem uma ação, que é o Indique Gain.
# [04:43.100 --> 04:46.100]  Aqui nessa informação que está aqui,
# [04:46.100 --> 04:48.100]  ou a informação padrão,
# [04:48.100 --> 04:51.100]  que você indicando uma pessoa e essa pessoa fechar,
# [04:51.100 --> 04:54.100]  você e ela ganham 68 reais de crédito,
# [04:54.100 --> 04:56.100]  que pode ser usado para bater na mensalidade.
# [04:57.100 --> 05:00.100]  Porém, agora no mês de junho, a gente está com uma ação um pouquinho difícil.
# Transcrevendo parte_005.mp3...
# [00:00.000 --> 00:07.140]  diferente. Se você indicar uma pessoa e ela fechar, em 30 dias você ganha um PIX de R$100,
# [00:07.140 --> 00:17.060]  se essa pessoa fechar com o Banco Cora, ganha R$50, só no mês de junho, tá? Aí é só,
# [00:17.060 --> 00:25.580]  esqueci de falar, desculpa, aí é só, oh meu Deus, por o e-mail dessa pessoa aqui ou
# [00:25.580 --> 00:32.860]  passar para ela o seu CNPJ, que é o seu código de desconto. Aqui nessa abinha de serviços,
# [00:32.860 --> 00:38.300]  são serviços adicionais, eles não estão nas contratações, são documentos bastante
# [00:38.300 --> 00:43.700]  específicos e se por ventura você estiver passando ali por alguma situação que for necessário um
# [00:43.700 --> 00:48.140]  documento desse, você consegue fazer essa contratação avulsa, então aqui vai ter o nome
# [00:48.140 --> 00:54.860]  técnico do documento, a descrição do que quer cada um, o valor dessa contratação e a
# [00:54.940 --> 01:00.820]  solicitação, que vai direto lá para o time responsável por elaborar e fazer a entrega do
# [01:00.820 --> 01:10.140]  documento solicitado. Eu não passei aqui sobre as movimentações, você já tem conta PJ?
# [01:10.140 --> 01:21.620]  Ah, legal. Na sua empresa você trabalha com caixa físico, trabalha com dinheiro em espécie ou as suas
# [01:21.620 --> 01:32.900]  informações são lá no banco mesmo, concentrado no banco. Aqui no banco, movimentações,
# [01:32.900 --> 01:39.140]  lançamento banco, você consegue adicionar a sua conta, dependendo do banco, tenha a importação
# [01:39.140 --> 01:43.820]  automática, você consegue fazer as categorizações, essas informações são importantes também,
# [01:43.820 --> 01:52.220]  porque elas ajudam a construção do imposto de renda PJ. Qual que é o seu banco?
# [01:58.300 --> 02:05.180]  Não vou lembrar de cabeça agora, eu perguntei porque alguns bancos têm importação automática e aí
# [02:05.180 --> 02:10.740]  ele fica trazendo lá o extrato, aí quando acaba o mês você só precisa vir aqui dar nome para essa
# [02:10.740 --> 02:19.540]  organização. Quando não tem, você precisa colocar ali o extrato de forma manual. Você
# [02:19.540 --> 02:24.300]  quer cadastrar a conta para a gente simular como faz ou você quer fazer isso depois?
# [02:24.300 --> 02:45.180]  Se você está fazendo cadastro por aí, só nessa parte aqui precisa se atentar,
# [02:45.180 --> 02:49.860]  não coloca, mesmo que tenha algum valor na sua conta, sempre zero aqui, tá bom?
# [02:54.300 --> 03:12.500]  Isso, não precisa alterar, aí você pode cadastrar mais de uma conta se você quiser, tá bom?
# [03:12.500 --> 03:31.060]  Isso, aí aqui no botãozinho importação, é onde você vai descobrir se esse banco permite,
# [03:31.060 --> 03:37.500]  vamos ver, olha lá, o secretário tem, aí só não clica agora porque ele vai travar a plataforma,
# [03:37.700 --> 03:44.180]  eu não consigo te mostrar as outras informações, tá? Mas aí você vem aqui, importação automática,
# [03:44.180 --> 03:58.980]  clica aqui no ativar, ele vai te mandar um ok lá no seu aplicativo, mesmo do banco que está no
# [03:58.980 --> 04:06.940]  seu celular, aí por lá que você faz a autorização, as duas plataformas começam a conversar e aí o
# [04:07.260 --> 04:14.220]  começa a trazer aqui o extrato, é só o extrato de entrada e saída e aí você só vai categorizar
# [04:14.220 --> 04:22.620]  isso no final do mês, tá? No final não, perdão, no mês seguinte, porque cada vez que você sobe um
# [04:22.620 --> 04:30.220]  extrato, a plataforma ela descarta o anterior e o uso atual, se você categorizar e ela fizer esse
# [04:30.220 --> 04:35.260]  processo, tudo que você categorizou ali você perde, então para você não ter retrabalho,
# [04:35.340 --> 04:41.060]  espera o mês acabar que aí é certeza que não tem nenhum tipo de movimentação na conta e aí sim
# [04:41.060 --> 04:47.860]  categoriza, tá? Eu vou fazer um lançamento aqui só para a gente simular e aí eu apago ele,
# [04:47.860 --> 04:59.220]  vamos supor que hoje no dia 13 teve uma movimentação chamada Bix no valor de R$2.000 e por agora foi uma
# Transcrevendo parte_006.mp3...
# [00:00.000 --> 00:04.400]  Esse nome PIX aqui é só para simular o que já aparece no seu extrato.
# [00:04.400 --> 00:09.300]  Quando você importa o extrato, a plataforma já separa o que é a entrada e o que é a saída.
# [00:09.300 --> 00:12.500]  Aqui vai estar o nome do pagador ou o recebedor.
# [00:12.500 --> 00:16.500]  E o que a gente vai, de fato, mexer é essa parte que está em vermelho aqui.
# [00:18.000 --> 00:23.300]  Isso. Então, se a gente está aqui em entrada, a categoria também já está em entrada.
# [00:23.300 --> 00:26.200]  Se você clicar lá no saída, ela muda sozinho aqui também.
# [00:26.600 --> 00:30.200]  Esses aqui são assuntos relacionados à entrada.
# [00:30.200 --> 00:37.000]  Então, tudo que entra na conta PJ se refere teoricamente a recebimento de serviço
# [00:37.000 --> 00:42.500]  que a sua empresa prestou ou de venda de algum item que a sua empresa vendeu.
# [00:42.500 --> 00:50.600]  Quando a gente está falando disso, a gente está falando então sobre os clientes e sobre nota fiscal.
# [00:50.600 --> 00:52.800]  Então, não tem segredo.
# [00:52.800 --> 00:56.100]  Clica aqui para selecionar essa movimentação.
# [00:56.100 --> 01:04.000]  Vem aqui nesse assunto de cliente e nota fiscal e procura o recebimento de nota fiscal.
# [01:06.400 --> 01:07.800]  É sempre isso.
# [01:07.800 --> 01:09.400]  Clica lá no vincular.
# [01:10.700 --> 01:12.400]  Pronto, está categorizado.
# [01:12.400 --> 01:17.800]  Se a gente está falando que esse dinheiro se refere ao pagamento de algum serviço prestado
# [01:17.800 --> 01:24.000]  ou o recebimento também da venda de algum item da sua empresa.
# [01:24.000 --> 01:29.600]  Então, é cliente mandando dinheiro para sua conta, independente se serviço ou produto.
# [01:30.600 --> 01:34.500]  Quando a gente está falando aqui, onde a gente está lançamento banco,
# [01:34.500 --> 01:38.800]  a gente está falando do dinheiro digital porque vai entrar o extrato.
# [01:38.800 --> 01:44.700]  Se você for fazer as movimentações desse dinheiro físico, aí é aqui o lançamento caixa,
# [01:44.700 --> 01:45.700]  mas a lógica é a mesma.
# [01:45.700 --> 01:52.800]  A diferença é que aqui, você vai ter que fazer a venda de algum item da sua empresa.
# [01:52.800 --> 01:57.700]  Esse dinheiro físico, aí é aqui o lançamento caixa, mas a lógica é a mesma.
# [01:57.700 --> 02:01.000]  A diferença é que aqui, você não tem um arquivo,
# [02:01.000 --> 02:06.100]  você não tem um documento ali para importar aqui para dar esses valores, esses nomes.
# [02:06.100 --> 02:11.100]  Então, você vai precisar lançar aqui manual, adicionar lançamento,
# [02:11.100 --> 02:14.900]  aí informa o dia que entrou, saiu, aquele que nem eu fiz agora.
# [02:14.900 --> 02:21.600]  Vamos porque hoje no dia 13, teve uma movimentação no nome PIX,
# [02:21.700 --> 02:28.200]  no valor de 3 mil, aí se é uma entrada, se o dinheiro entrou no seu caixa,
# [02:28.200 --> 02:30.200]  bota aqui entrada, adicionar, pronto.
# [02:31.200 --> 02:33.600]  Já vai estar lá para categorizar.
# [02:33.600 --> 02:39.700]  Agora, se foi um dinheiro que você tirou do seu caixa físico para pagar alguma conta,
# [02:39.700 --> 02:44.200]  para comprar um item para revender, enfim, vai aqui, saída.
# [02:45.200 --> 02:50.700]  E aí, ele já saiu daqui de entrada, ele está aqui em saída.
# [02:55.200 --> 02:59.400]  Aqui também a gente entrou em saída, então aqui é o tirou também, já está em saída.
# [02:59.400 --> 03:03.200]  Você vê que em saída tem muito mais assuntos, a barrinha corre.
# [03:05.200 --> 03:12.400]  E a lógica é a mesma, seleciona a movimentação bem aqui nos assuntos,
# [03:12.400 --> 03:17.600]  escolhe do que se refere a essa saída, e aí aqui embaixo do que foi.
# [03:17.600 --> 03:21.400]  Então, a gente está falando sobre serviços, o assunto é serviço.
# [03:21.400 --> 03:25.000]  O que aconteceu aqui? Foi pagamento da senhora contábil, por exemplo?
# [03:26.000 --> 03:28.000]  Contabilidade, senhora contábil.
# [03:29.400 --> 03:35.000]  Correios, precisei fazer uma entrega de uma mercadoria, uma venda online, por exemplo.
# [03:35.400 --> 03:38.200]  Tive custo ali com correio, então foi pago.
# [03:39.200 --> 03:44.200]  É isso, ficou alguma dúvida em relação às movimentações?
# [03:51.200 --> 03:53.200]  Ah, que legal.
# [04:04.200 --> 04:06.200]  Ah, entendi.
# [04:08.200 --> 04:10.200]  Sim, nossa, muito mais fácil.
# [04:10.200 --> 04:15.200]  É, o bom daqui é que se você colocar aqui no lançamento cache, por exemplo,
# [04:15.200 --> 04:18.200]  você já tem controle sobre isso também.
# [04:18.200 --> 04:21.200]  Se você precisar acessar, você está em um lugar, seu pai está no outro,
# [04:21.200 --> 04:25.200]  e os dois precisam de informação, é só acessar a plataforma.
# [04:27.200 --> 04:31.200]  E aí, olha, você pode acessar, você pode acessar, você pode acessar,
# [04:31.200 --> 04:34.200]  você pode acessar, você pode acessar, você pode acessar,
# [04:34.200 --> 04:36.200]  você pode acessar a plataforma.
# [04:38.200 --> 04:41.200]  E aí, olha, aqui, eu tinha feito aqui esse lançamento,
# [04:41.200 --> 04:44.200]  eu vou apagar aqui também para não ter nenhum problema
# [04:44.200 --> 04:46.200]  quando você colocar o seu extrato, tá?
# [04:46.200 --> 04:48.200]  Não tem nenhuma confusão.
# [04:52.200 --> 04:54.200]  Pronto.
# [04:54.200 --> 04:57.200]  Então, não está nem entrada nem saída, está tudo ok, tá bom?
# [04:59.200 --> 05:01.200]  Então, assim...
# Transcrevendo parte_007.mp3...
# [00:00.000 --> 00:04.700]  Ficou ok? Você quer que eu volte a algum ponto aqui da movimentação?
# [00:06.800 --> 00:07.800]  Maravilha.
# [00:07.800 --> 00:12.100]  Então, a gente já viu aqui em relação aos impostos, as declarações,
# [00:12.100 --> 00:15.300]  aba sócio, que não precisa alimentar por enquanto.
# [00:15.300 --> 00:18.900]  O funcionário MEI pode ter até um funcionário, né?
# [00:18.900 --> 00:23.300]  Se você quiser fazer essa contratação, você tem aqui o respaldo também dessa contratação,
# [00:23.300 --> 00:25.200]  no caso de demissão também.
# [00:25.200 --> 00:28.500]  E aí, você já até tem aqui um funcionário.
# [00:31.000 --> 00:33.800]  Ah, que legal, muito bom.
# [00:33.800 --> 00:37.100]  E aí, você tem esse respaldo aqui,
# [00:37.100 --> 00:39.700]  vai ser liberado para você lá na guia dos impostos também,
# [00:39.700 --> 00:42.500]  os impostos pertinentes a essa contratação, tá?
# [00:43.500 --> 00:44.500]  Que legal.
# [00:45.500 --> 00:47.700]  Indicação aqui, a gente conversou.
# [00:47.700 --> 00:50.500]  Serviços também, a mensalidade.
# [00:53.000 --> 00:55.500]  Não lembro se eu passei todas as informações.
# [00:56.000 --> 01:01.300]  Aqui, você consegue acompanhar se existe alguma mensalidade dependente,
# [01:01.300 --> 01:06.200]  seus históricos de pagamento, escolher a forma de pagamento,
# [01:06.200 --> 01:08.000]  se você quer deixar manual,
# [01:08.000 --> 01:13.500]  todo mês você escolhe se vai ser no PICOS, no boleto, no cartão de crédito,
# [01:13.500 --> 01:16.800]  ou se você prefere deixar recorrente mesmo no cartão de crédito,
# [01:16.800 --> 01:20.300]  a gente só pede para que, caso seja o cartão de crédito,
# [01:20.300 --> 01:22.600]  seja o cartão de crédito da conta PJ,
# [01:22.600 --> 01:25.100]  para você não ter ali nenhuma divergência
# [01:25.100 --> 01:29.100]  na hora de fazer as movimentações, tá?
# [01:31.600 --> 01:34.600]  Então, assim, Joana, do mais eram essas as informações
# [01:34.600 --> 01:37.100]  que eu precisava te trazer em relação à plataforma,
# [01:37.100 --> 01:39.100]  você quer que eu volte em algum assunto,
# [01:39.100 --> 01:40.600]  ficou alguma dúvida.
# [01:44.600 --> 01:46.600]  É que agora a gente também está conversando aqui,
# [01:46.600 --> 01:49.600]  você não está mexendo, mas se a hora que você for fazer...
# [01:49.600 --> 01:50.600]  Ah, é?
# [01:51.600 --> 01:52.600]  Ah, tá maravilha.
# [01:52.600 --> 01:55.600]  Se surgir qualquer dúvida, chama a gente ali no WhatsApp,
# [01:55.600 --> 01:58.600]  não fica com a dúvida e a gente vai te auxiliando, tá?
# [01:59.600 --> 02:02.100]  Tá certo, então, muito obrigada,
# [02:02.100 --> 02:05.600]  excelente tarde, excelente final de semana aí para vocês, viu?
# [02:07.600 --> 02:09.600]  Por favor, não fica com a dúvida.
# [02:10.600 --> 02:12.100]  Obrigada, tchau, tchau.
# ✅ Transcrição finalizada. Baixe os arquivos .txt gerados.

# %%
# 6. Juntar todas as transcrições em um único arquivo final
arquivos_txt = sorted(glob.glob("parte_*.txt"))

with open("transcricao_final.txt", "w", encoding="utf-8") as final:
    for nome_txt in arquivos_txt:
        with open(nome_txt, "r", encoding="utf-8") as f:
            final.write(f"### {nome_txt} ###\n")
            final.write(f.read() + "\n\n")

print("✅ Transcrição final unificada em: transcricao_final.txt")
# Out:
# ✅ Transcrição final unificada em: transcricao_final.txt

# %%
#Excluir todos os arquivos para iniciar uma nova transcrição, OBS: atualize no botão após a exclusão
# !rm *.mp3
# !rm *.txt
# !rm -r whisper  # se tiver uma pasta gerada
# Out:
# rm: cannot remove '*.mp3': No such file or directory
# rm: cannot remove '*.txt': No such file or directory
# rm: cannot remove 'whisper': No such file or directory
